# %% [markdown]
# ## Задание по анализу данных и визуализации
#
# Этапы работы:
# - Выбрать данные, которые вам интересны, предпочтительно в табличной форме (Excel, CSV)
# - С помощью Pandas провести какой-то анализ данных и визуализацию
# - По возможности стилизовать визуализацию, чтобы получить некоторую консистентную инфографику в оригинальном стиле
#
# ### Выбор данных
#
# Рекомендумые ресурсы для поиска данных:
# * [Список от Yandex](https://yandex.ru/project/oda/useful)
# * [Kaggle](http://Kaggle.com) – сайт соревований для датасайнтистов. Там же можно искать код
# * Открытые данные:
#   - ищите в интернете по этим ключевым словам
#   - https://data.world/datasets/open-data
# * Различные текстовые данные, из которых можно извлечь что-то интересное:
#   - Видео на YouTube, у которых есть субтитры, или которые можно преобразовать в текст (см. пример)
#   - Библиотеки книг: [lib.ru](http://lib.ru), [Project Gutenberg](https://www.gutenberg.org/) и др.
# * Статьи:
#   - [15 of the Best Free Open Data Sources for 2024](https://careerfoundry.com/en/blog/data-analytics/open-data-sources/)
#
# ### Анализ данных
#
# Для анализа данных используем Pandas. Если вы не знаете, как сделать какую-то операцию:
# * Ищем в интернет (как правило, хорошие ответы находятся на сайте stackoverflow.com)
# * Спрашиваем [у ChatGPT](https://soshnikov.com/ai/how-to-use-chatgpt-ru/)

# %%
import pandas as pd

# df = pd.read_csv(...) # чтение файла CSV, иногда может потребоваться указать разделитель sep=';'
# df = pd.read_excel('titanic.xlsx') # чтение файла Excel

# %%
# 2015
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path = '/content/2015.csv'
data = pd.read_csv(file_path)

data_sorted = data.sort_values(by='Happiness Score', ascending=False)

top_50 = data_sorted.head(50)

colors = plt.cm.viridis(np.linspace(0.8, 0.2, len(top_50)))

plt.figure(figsize=(14, 6))
bars = plt.bar(top_50['Country'], top_50['Happiness Score'], color=colors)

plt.ylabel('Уровень счастья', fontsize=12)
plt.xlabel('Страна', fontsize=12)
plt.title('Топ-50 самых счастливых стран за 2015 год', fontsize=14)

plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(fontsize=9)
plt.grid(axis='y', linestyle='--', alpha=0.7)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=top_50['Happiness Score'].min(), vmax=top_50['Happiness Score'].max()))
sm.set_array([])
plt.colorbar(sm, label='Уровень счастья', pad=0.02)

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-7b77c883580d> in <cell line: 0>()
#      26 sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=top_50['Happiness Score'].min(), vmax=top_50['Happiness Score'].max()))
#      27 sm.set_array([])
# ---> 28 plt.colorbar(sm, label='Уровень счастья', pad=0.02)
#      29
#      30 plt.tight_layout()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kwargs)
#    2530                                'an image (with imshow) or a contour set ('
#    2531                                'with contourf).')
# -> 2532     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2533     return ret
#    2534
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
# ...

# %%
# 2016
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path = '/content/2016.csv'
data = pd.read_csv(file_path)

data_sorted = data.sort_values(by='Happiness Score', ascending=False)

top_50 = data_sorted.head(50)

colors = plt.cm.viridis(np.linspace(0.8, 0.2, len(top_50)))

plt.figure(figsize=(14, 6))
bars = plt.bar(top_50['Country'], top_50['Happiness Score'], color=colors)

plt.ylabel('Уровень счастья', fontsize=12)
plt.xlabel('Страна', fontsize=12)
plt.title('Топ-50 самых счастливых стран за 2016 год', fontsize=14)

plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(fontsize=9)
plt.grid(axis='y', linestyle='--', alpha=0.7)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=top_50['Happiness Score'].min(), vmax=top_50['Happiness Score'].max()))
sm.set_array([])
plt.colorbar(sm, label='Уровень счастья', pad=0.02)

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-fe9ec3981a9a> in <cell line: 0>()
#      26 sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=top_50['Happiness Score'].min(), vmax=top_50['Happiness Score'].max()))
#      27 sm.set_array([])
# ---> 28 plt.colorbar(sm, label='Уровень счастья', pad=0.02)
#      29
#      30 plt.tight_layout()
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kwargs)
#    2530                                'an image (with imshow) or a contour set ('
#    2531                                'with contourf).')
# -> 2532     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
#    2533     return ret
#    2534
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
# ...

# %%
# 2017
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file_path = '/content/2017.csv'
data = pd.read_csv(file_path)

data_sorted = data.sort_values(by='Happiness Score', ascending=False)

top_50 = data_sorted.head(50)

colors = plt.cm.viridis(np.linspace(0.8, 0.2, len(top_50)))

plt.figure(figsize=(14, 6))
bars = plt.bar(top_50['Country'], top_50['Happiness Score'], color=colors)

plt.ylabel('Уровень счастья', fontsize=12)
plt.xlabel('Страна', fontsize=12)
plt.title('Топ-50 самых счастливых стран за 2017 год', fontsize=14)

plt.xticks(rotation=45, ha='right', fontsize=9)
plt.yticks(fontsize=9)
plt.grid(axis='y', linestyle='--', alpha=0.7)

sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=top_50['Happiness Score'].min(), vmax=top_50['Happiness Score'].max()))
sm.set_array([])
plt.colorbar(sm, label='Уровень счастья', pad=0.02)

plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-f20bdb3cb4af> in <cell line: 0>()
#       7 data = pd.read_csv(file_path)
#       8
# ----> 9 data_sorted = data.sort_values(by='Happiness Score', ascending=False)
#      10
#      11 top_50 = data_sorted.head(50)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# ...
